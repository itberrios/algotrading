# %%
import yfinance as yf
import seaborn as sn
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting Data

# %%
tickers = ['AAPL', 'MSFT', 'AMZN', 'TSLA', 'GOOGL', 'GOOG', 'META', 'NVDA', 'CSCO', 'ADBE', 'QCOM', 'ORCL', 'IBM', 'INTC', 'NFLX', 'PYPL', 'SONY', 'ABNB', 'SQ']

def get_price_history(ticker, save=True, START_DATE = '2022-9-12', END_DATE = '2022-11-10', RAW_INTERVAL = "5m"):

    tickerData = yf.Ticker(ticker)
    df = tickerData.history(interval=RAW_INTERVAL,  start=START_DATE, end=END_DATE)
    
    if save:
        df.to_csv("data/yahoo/{}_5m.csv".format(ticker), index=False)

for ticker in tickers:
    get_price_history(ticker)
        
data = []

for csv_file in glob.glob("data/yahoo/*_5m.csv"):
    df = pd.read_csv(csv_file)
    data.append(df)
    print(csv_file, df.shape[0])
# Out:
# data/yahoo\AAPL_15m.csv 1040
# data/yahoo\AAPL_5m.csv 3355
# data/yahoo\ABNB_15m.csv 1093
# data/yahoo\ABNB_5m.csv 3121
# data/yahoo\ADBE_15m.csv 1093
# data/yahoo\ADBE_5m.csv 3355
# data/yahoo\AMZN_15m.csv 1093
# data/yahoo\AMZN_5m.csv 3355
# data/yahoo\CSCO_15m.csv 1093
# data/yahoo\CSCO_5m.csv 3355
# data/yahoo\GOOGL_15m.csv 1093
# data/yahoo\GOOGL_5m.csv 3355
# data/yahoo\GOOG_15m.csv 1040
# data/yahoo\GOOG_5m.csv 3355
# data/yahoo\IBM_15m.csv 1093
# data/yahoo\IBM_5m.csv 3355
# data/yahoo\INTC_15m.csv 1093
# data/yahoo\INTC_5m.csv 3355
# data/yahoo\META_15m.csv 1093
# data/yahoo\META_5m.csv 3355
# data/yahoo\MSFT_15m.csv 1093
# data/yahoo\MSFT_5m.csv 3355
# data/yahoo\NFLX_15m.csv 1089
# data/yahoo\NFLX_5m.csv 3251
# data/yahoo\NVDA_15m.csv 1093
# data/yahoo\NVDA_5m.csv 3355
# data/yahoo\ORCL_15m.csv 1093
# data/yahoo\ORCL_5m.csv 3355
# data/yahoo\PYPL_15m.csv 1093
# data/yahoo\PYPL_5m.csv 3355
# data/yahoo\QCOM_15m.csv 1040
# data/yahoo\QCOM_5m.csv 3355
# data/yahoo\SONY_15m.csv 1093
# data/yahoo\SONY_5m.csv 3355
# data/yahoo\SQ_15m.csv 1093
# data/yahoo\SQ_5m.csv 3355
# data/yahoo\TSLA_15m.csv 1040
# data/yahoo\TSLA_5m.csv 3355

# %% [markdown]
# ## Correlation Matrix

# %%
close_prices = pd.DataFrame(columns=tickers)
for i in range(len(tickers)):
    close_prices[tickers[i]] = data[i]['Close']
    
corrMatrix = close_prices.corr()
corrMatrix
# Out:
#            AAPL      MSFT      AMZN      TSLA     GOOGL      GOOG      META  \
# AAPL   1.000000  0.425056  0.875625  0.900138  0.849723  0.926760  0.926077
# MSFT   0.425056  1.000000  0.478937  0.609726  0.487337  0.471648  0.480432
# AMZN   0.875625  0.478937  1.000000  0.954383  0.859952  0.968478  0.970272
# TSLA   0.900138  0.609726  0.954383  1.000000  0.829972  0.975835  0.977076
# GOOGL  0.849723  0.487337  0.859952  0.829972  1.000000  0.836154  0.842279
# GOOG   0.926760  0.471648  0.968478  0.975835  0.836154  1.000000  0.999766
# META   0.926077  0.480432  0.970272  0.977076  0.842279  0.999766  1.000000
# NVDA   0.938844  0.427393  0.869822  0.871778  0.925805  0.895103  0.895620
# CSCO   0.899624  0.371335  0.930622  0.939684  0.810305  0.969463  0.967480
# ADBE   0.871681  0.578516  0.948434  0.944968  0.834836  0.953174  0.956732
# QCOM   0.949954  0.439456  0.963636  0.965883  0.844340  0.992842  0.992342
# ORCL   0.368519  0.473595  0.113684  0.303614  0.138656  0.277114  0.275410
# IBM    0.907056  0.328528  0.881722  0.915091  0.746752  0.946279  0.942588
# INTC   0.838706  0.563617  0.959050  0.929440  0.906715  0.919758  0.923978
# NFLX   0.698793  0.841101  0.708107  0.797976  0.672315  0.724755  0.732231
# PYPL   0.926152  0.390617  0.907974  0.943869  0.780499  0.965416  0.962689
# SONY   0.908874  0.337577  0.923240  0.920844  0.836692  0.959330  0.958686
# ABNB   0.796903  0.578561  0.899481  0.957302  0.670966  0.930733  0.930598
# SQ     0.384904  0.609861  0.233151  0.446160  0.260821  0.329611  0.326487
#
#            NVDA      CSCO      ADBE      QCOM      ORCL       IBM      INTC  \
# AAPL   0.938844  0.899624  0.871681  0.949954  0.368519  0.907056  0.838706
# MSFT   0.427393  0.371335  0.578516  0.439456  0.473595  0.328528  0.563617
# AMZN   0.869822  0.930622  0.948434  0.963636  0.113684  0.881722  0.959050
# TSLA   0.871778  0.939684  0.944968  0.965883  0.303614  0.915091  0.929440
# GOOGL  0.925805  0.810305  0.834836  0.844340  0.138656  0.746752  0.906715
# GOOG   0.895103  0.969463  0.953174  0.992842  0.277114  0.946279  0.919758
# META   0.895620  0.967480  0.956732  0.992342  0.275410  0.942588  0.923978
# NVDA   1.000000  0.889508  0.832098  0.912755  0.263213  0.866818  0.878631
# CSCO   0.889508  1.000000  0.884618  0.967784  0.190554  0.973544  0.895114
# ADBE   0.832098  0.884618  1.000000  0.937186  0.314328  0.826377  0.930239
# QCOM   0.912755  0.967784  0.937186  1.000000  0.274240  0.954775  0.908337
# ORCL   0.263213  0.190554  0.314328  0.274240  1.000000  0.247057  0.090993
# IBM    0.866818  0.973544  0.826377  0.954775  0.247057  1.000000  0.811653
# INTC   0.878631  0.895114  0.930239  0.908337  0.090993  0.811653  1.000000
# NFLX   0.669533  0.600024  0.803937  0.704850  0.511109  0.580631  0.732146
# PYPL   0.889535  0.983011  0.866288  0.970171  0.271794  0.990591  0.850670
# SONY   0.907071  0.985153  0.876610  0.962014  0.156571  0.963144  0.891808
# ABNB   0.741069  0.894909  0.895347  0.909436  0.297395  0.886512  0.844275
# SQ     0.393659  0.339651  0.249744  0.322981  0.519857  0.400580  0.276493
#
#            NFLX      PYPL      SONY      ABNB        SQ
# AAPL   0.698793  0.926152  0.908874  0.796903  0.384904
# MSFT   0.841101  0.390617  0.337577  0.578561  0.609861
# AMZN   0.708107  0.907974  0.923240  0.899481  0.233151
# TSLA   0.797976  0.943869  0.920844  0.957302  0.446160
# GOOGL  0.672315  0.780499  0.836692  0.670966  0.260821
# GOOG   0.724755  0.965416  0.959330  0.930733  0.329611
# META   0.732231  0.962689  0.958686  0.930598  0.326487
# NVDA   0.669533  0.889535  0.907071  0.741069  0.393659
# CSCO   0.600024  0.983011  0.985153  0.894909  0.339651
# ADBE   0.803937  0.866288  0.876610  0.895347  0.249744
# QCOM   0.704850  0.970171  0.962014  0.909436  0.322981
# ORCL   0.511109  0.271794  0.156571  0.297395  0.519857
# IBM    0.580631  0.990591  0.963144  0.886512  0.400580
# INTC   0.732146  0.850670  0.891808  0.844275  0.276493
# NFLX   1.000000  0.636354  0.595924  0.762911  0.517750
# PYPL   0.636354  1.000000  0.969027  0.908173  0.410427
# SONY   0.595924  0.969027  1.000000  0.867964  0.282072
# ABNB   0.762911  0.908173  0.867964  1.000000  0.431821
# SQ     0.517750  0.410427  0.282072  0.431821  1.000000

# %% [markdown]
# ## Heat Map

# %%
fig, ax = plt.subplots(figsize=(10,10))
sn.heatmap(corrMatrix, ax=ax)
plt.show()

# %% [markdown]
# ## Correlation by pairs

# %%
correlation_by_pairs = []
for i in range(len(tickers)):
    for j in range(i+1,len(tickers)):
        ticker1, ticker2 = tickers[i], tickers[j]
        corr_coef = close_prices[ticker1].corr(close_prices[ticker2])
        correlation_by_pairs.append([ticker1, ticker2, corr_coef])

# sort pairs of stocks based on their correlation coefficient
correlation_by_pairs.sort(key=lambda x: x[2], reverse=True)
correlation_by_pairs
# Out:
# [['GOOG', 'META', 0.9997661128883215],
#  ['GOOG', 'QCOM', 0.9928423441103112],
#  ['META', 'QCOM', 0.9923418527498525],
#  ['IBM', 'PYPL', 0.9905913460521992],
#  ['CSCO', 'SONY', 0.9851531585265876],
#  ['CSCO', 'PYPL', 0.9830110650941468],
#  ['TSLA', 'META', 0.9770764424781649],
#  ['TSLA', 'GOOG', 0.9758353829015693],
#  ['CSCO', 'IBM', 0.9735441611530476],
#  ['AMZN', 'META', 0.9702720397975216],
#  ['QCOM', 'PYPL', 0.9701705162624039],
#  ['GOOG', 'CSCO', 0.9694630340392147],
#  ['PYPL', 'SONY', 0.969027066534204],
#  ['AMZN', 'GOOG', 0.9684783439506454],
#  ['CSCO', 'QCOM', 0.9677840527222087],
#  ['META', 'CSCO', 0.9674796073343821],
#  ['TSLA', 'QCOM', 0.9658832862649054],
#  ['GOOG', 'PYPL', 0.9654164741163155],
#  ['AMZN', 'QCOM', 0.9636362552432074],
#  ['IBM', 'SONY', 0.9631435219969626],
#  ['META', 'PYPL', 0.9626893498636906],
#  ['QCOM', 'SONY', 0.9620144286865797],
#  ['GOOG', 'SONY', 0.9593304311251922],
#  ['AMZN', 'INTC', 0.9590496679364621],
#  ['META', 'SONY', 0.9586859535365174],
#  ['TSLA', 'ABNB', 0.9573016382098094],
#  ['META', 'ADBE', 0.956731616456648],
#  ['QCOM', 'IBM', 0.9547749666404863],
#  ['AMZN', 'TSLA', 0.9543826626032778],
#  ['GOOG', 'ADBE', 0.9531739625923901],
#  ['AAPL', 'QCOM', 0.9499536209274334],
#  ['AMZN', 'ADBE', 0.9484341826994754],
#  ['GOOG', 'IBM', 0.9462789588684329],
#  ['TSLA', 'ADBE', 0.9449678759640253],
#  ['TSLA', 'PYPL', 0.9438693919433561],
#  ['META', 'IBM', 0.9425875567983507],
#  ['TSLA', 'CSCO', 0.9396838506602887],
#  ['AAPL', 'NVDA', 0.9388444513924165],
#  ['ADBE', 'QCOM', 0.9371862678445149],
#  ['GOOG', 'ABNB', 0.9307330163861782],
#  ['AMZN', 'CSCO', 0.9306215475251418],
#  ['META', 'ABNB', 0.9305980659595131],
#  ['ADBE', 'INTC', 0.9302387369997233],
#  ['TSLA', 'INTC', 0.9294403010266937],
#  ['AAPL', 'GOOG', 0.9267597417438634],
#  ['AAPL', 'PYPL', 0.926151991242087],
#  ['AAPL', 'META', 0.9260773508892091],
#  ['GOOGL', 'NVDA', 0.9258049639055298],
#  ['META', 'INTC', 0.9239784579724447],
#  ['AMZN', 'SONY', 0.9232398072891291],
#  ['TSLA', 'SONY', 0.9208439404817279],
#  ['GOOG', 'INTC', 0.9197580908945701],
#  ['TSLA', 'IBM', 0.9150910256955541],
#  ['NVDA', 'QCOM', 0.9127551658200389],
#  ['QCOM', 'ABNB', 0.9094364224528391],
#  ['AAPL', 'SONY', 0.9088741655380959],
#  ['QCOM', 'INTC', 0.9083367248346036],
#  ['PYPL', 'ABNB', 0.9081727639393417],
#  ['AMZN', 'PYPL', 0.9079739619305556],
#  ['NVDA', 'SONY', 0.9070710521660023],
#  ['AAPL', 'IBM', 0.9070556849640385],
#  ['GOOGL', 'INTC', 0.9067147729866927],
#  ['AAPL', 'TSLA', 0.9001380915768682],
#  ['AAPL', 'CSCO', 0.899623711253615],
#  ['AMZN', 'ABNB', 0.8994807590712349],
#  ['META', 'NVDA', 0.8956203157293464],
#  ['ADBE', 'ABNB', 0.8953469864337935],
#  ['CSCO', 'INTC', 0.8951141059721902],
#  ['GOOG', 'NVDA', 0.8951034227736169],
#  ['CSCO', 'ABNB', 0.8949092129540408],
#  ['INTC', 'SONY', 0.8918081289754736],
#  ['NVDA', 'PYPL', 0.8895347958400408],
#  ['NVDA', 'CSCO', 0.8895079189185647],
#  ['IBM', 'ABNB', 0.8865117337636664],
#  ['CSCO', 'ADBE', 0.8846183439049895],
#  ['AMZN', 'IBM', 0.8817222035584183],
#  ['NVDA', 'INTC', 0.8786305440261406],
#  ['ADBE', 'SONY', 0.8766099698045503],
#  ['AAPL', 'AMZN', 0.875624980406026],
#  ['TSLA', 'NVDA', 0.8717783433832464],
#  ['AAPL', 'ADBE', 0.8716809931844758],
#  ['AMZN', 'NVDA', 0.8698221085755443],
#  ['SONY', 'ABNB', 0.8679643151171852],
#  ['NVDA', 'IBM', 0.8668182317502493],
#  ['ADBE', 'PYPL', 0.8662880164898579],
#  ['AMZN', 'GOOGL', 0.859951966078054],
#  ['INTC', 'PYPL', 0.8506702320464833],
#  ['AAPL', 'GOOGL', 0.8497228806307903],
#  ['GOOGL', 'QCOM', 0.8443403522888404],
#  ['INTC', 'ABNB', 0.8442751673077797],
#  ['GOOGL', 'META', 0.842279411799408],
#  ['MSFT', 'NFLX', 0.8411007801071171],
#  ['AAPL', 'INTC', 0.8387063419154814],
#  ['GOOGL', 'SONY', 0.836692368243836],
#  ['GOOGL', 'GOOG', 0.836153548910536],
#  ['GOOGL', 'ADBE', 0.8348359532410282],
#  ['NVDA', 'ADBE', 0.8320984612819403],
#  ['TSLA', 'GOOGL', 0.8299717709266932],
#  ['ADBE', 'IBM', 0.8263769537440124],
#  ['IBM', 'INTC', 0.8116526830872061],
#  ['GOOGL', 'CSCO', 0.8103054872795142],
#  ['ADBE', 'NFLX', 0.8039365563922887],
#  ['TSLA', 'NFLX', 0.7979761546837808],
#  ['AAPL', 'ABNB', 0.796902807533499],
#  ['GOOGL', 'PYPL', 0.7804992094010167],
#  ['NFLX', 'ABNB', 0.762911141042932],
#  ['GOOGL', 'IBM', 0.7467519856038082],
#  ['NVDA', 'ABNB', 0.7410685268000766],
#  ['META', 'NFLX', 0.7322306197536333],
#  ['INTC', 'NFLX', 0.7321464072375113],
#  ['GOOG', 'NFLX', 0.724754766543384],
#  ['AMZN', 'NFLX', 0.7081068550761142],
#  ['QCOM', 'NFLX', 0.7048495381279348],
#  ['AAPL', 'NFLX', 0.6987934279380548],
#  ['GOOGL', 'NFLX', 0.672314795477097],
#  ['GOOGL', 'ABNB', 0.6709664634863167],
#  ['NVDA', 'NFLX', 0.6695326240914808],
#  ['NFLX', 'PYPL', 0.6363535675927001],
#  ['MSFT', 'SQ', 0.6098612096023814],
#  ['MSFT', 'TSLA', 0.6097256462474888],
#  ['CSCO', 'NFLX', 0.6000236134010254],
#  ['NFLX', 'SONY', 0.595923631162315],
#  ['IBM', 'NFLX', 0.5806311016571175],
#  ['MSFT', 'ABNB', 0.5785613250165655],
#  ['MSFT', 'ADBE', 0.5785163426551198],
#  ['MSFT', 'INTC', 0.5636166286076054],
#  ['ORCL', 'SQ', 0.5198565665511734],
#  ['NFLX', 'SQ', 0.5177496476843798],
#  ['ORCL', 'NFLX', 0.5111092350405886],
#  ['MSFT', 'GOOGL', 0.48733691554117003],
#  ['MSFT', 'META', 0.48043213676179686],
#  ['MSFT', 'AMZN', 0.4789365853564823],
#  ['MSFT', 'ORCL', 0.4735947741878178],
#  ['MSFT', 'GOOG', 0.47164770459809796],
#  ['TSLA', 'SQ', 0.44616014473482923],
#  ['MSFT', 'QCOM', 0.43945580227165826],
#  ['ABNB', 'SQ', 0.4318208447633978],
#  ['MSFT', 'NVDA', 0.427393228278018],
#  ['AAPL', 'MSFT', 0.42505642539581256],
#  ['PYPL', 'SQ', 0.41042714780020645],
#  ['IBM', 'SQ', 0.4005798938006198],
#  ['NVDA', 'SQ', 0.39365897466198385],
#  ['MSFT', 'PYPL', 0.39061670289849],
#  ['AAPL', 'SQ', 0.3849039885928874],
#  ['MSFT', 'CSCO', 0.3713351605481219],
#  ['AAPL', 'ORCL', 0.3685191255920126],
#  ['CSCO', 'SQ', 0.3396511434089007],
#  ['MSFT', 'SONY', 0.33757707303494155],
#  ['GOOG', 'SQ', 0.3296111074142059],
#  ['MSFT', 'IBM', 0.3285283578683009],
#  ['META', 'SQ', 0.32648701042595385],
#  ['QCOM', 'SQ', 0.3229806933520667],
#  ['ADBE', 'ORCL', 0.3143282269912185],
#  ['TSLA', 'ORCL', 0.3036142977553854],
#  ['ORCL', 'ABNB', 0.2973949000864954],
#  ['SONY', 'SQ', 0.28207233535570514],
#  ['GOOG', 'ORCL', 0.2771137026497956],
#  ['INTC', 'SQ', 0.27649276344189627],
#  ['META', 'ORCL', 0.2754104374708537],
#  ['QCOM', 'ORCL', 0.2742395014576446],
#  ['ORCL', 'PYPL', 0.2717936841833155],
#  ['NVDA', 'ORCL', 0.26321264966329194],
#  ['GOOGL', 'SQ', 0.26082072061710904],
#  ['ADBE', 'SQ', 0.2497442827906763],
#  ['ORCL', 'IBM', 0.24705731182450047],
#  ['AMZN', 'SQ', 0.23315123969359883],
#  ['CSCO', 'ORCL', 0.1905543408310825],
#  ['ORCL', 'SONY', 0.15657140384979024],
#  ['GOOGL', 'ORCL', 0.1386561619929991],
#  ['AMZN', 'ORCL', 0.11368393951296771],
#  ['ORCL', 'INTC', 0.09099273267519617]]

# %%
best_group = ['GOOG', 'META', 'TSLA', 'QCOM']
best_group_corr_coefs = []
for i in range(len(best_group)):
    for j in range(i+1, len(best_group)):
        corr_coef = close_prices[best_group[i]].corr(close_prices[best_group[j]])
        best_group_corr_coefs.append(corr_coef)
np.mean(best_group_corr_coefs)
# Out:
# 0.9839575702321876
